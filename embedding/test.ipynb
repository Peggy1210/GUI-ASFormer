# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# frame extraction

# %%
import os 
from video2img import *
abspath = os.path.join(os.getcwd(),'..')
videos_folder = os.path.join(abspath,'videos')
ft_folder = os.path.join(abspath,'features')
target_fps = 30
batch_size = (192,192)
embedding = ImgEmbedding()
embedding.set_model(model_name="test")

video2img(videos_folder=videos_folder,target_fps=target_fps,batch_size=batch_size,ft_folder=ft_folder,embedding=embedding)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# extracting features from gui_world_104
# 100%|██████████| 2/2 [00:19<00:00,  9.98s/it]
# gui_world_104 feature extraction completed.
# shape:torch.Size([216, 1024])
