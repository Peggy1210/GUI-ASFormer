# %% [markdown]
# ## 1. Set up drive
#
# Remember to modify the directory to your workspace.

# %%
from google.colab import drive
drive.mount('/content/drive')

################# cd to your path #####################
# %cd /content/drive/MyDrive/EECS545/embedding
############################################################
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/.shortcut-targets-by-id/11_2mX3HssMx9kNfSG9fXNjJJ9jD_Ura5/embedding

# %% [markdown]
# ## 2. Download videos
#
# The part will automatically download the videos from Huggingface to `work_dir/data`

# %% [markdown]
# ### Getting video paths
#
# Change the index of videos you are going to download. The program will download the videos from paths indicated in the `website_files.txt`

# %%
##### Change the idex of video you want to generate #####
file_path = "website_files.txt"
start = 2000
end = 2100
###################################################################

# Below will download the video from start ~ end - 1
video_list = []
with open(file_path, "r") as f:
  video_list = f.readlines()

print(f"Total number of videos: {len(video_list)}")
print(f"Dowloading videos from index {start} to {end - 1}. Number of downloads: {end - start}")
video_list = video_list[start:end]
video_list = [line.strip() for line in video_list]
# Out:
# Total number of videos: 2499
# Dowloading videos from index 2000 to 2099. Number of downloads: 100

# %%
video_list
# Out:
# ['website/55.mp4',
#  'website/550.mp4',
#  'website/551.mp4',
#  'website/552.mp4',
#  'website/553.mp4',
#  'website/554.mp4',
#  'website/555.mp4',
#  'website/556.mp4',
#  'website/557.mp4',
#  'website/558.mp4',
#  'website/559.mp4',
#  'website/56.mp4',
#  'website/560.mp4',
#  'website/561.mp4',
#  'website/562.mp4',
#  'website/563.mp4',
#  'website/564.mp4',
#  'website/565.mp4',
#  'website/566.mp4',
#  'website/567.mp4',
#  'website/568.mp4',
#  'website/569.mp4',
#  'website/57.mp4',
#  'website/570.mp4',
#  'website/571.mp4',
#  'website/572.mp4',
#  'website/573.mp4',
#  'website/574.mp4',
#  'website/575.mp4',
#  'website/576.mp4',
#  'website/577.mp4',
#  'website/578.mp4',
#  'website/579.mp4',
#  'website/58.mp4',
#  'website/580.mp4',
#  'website/581.mp4',
#  'website/582.mp4',
#  'website/583.mp4',
#  'website/584.mp4',
#  'website/585.mp4',
#  'website/586.mp4',
#  'website/587.mp4',
#  'website/588.mp4',
#  'website/589.mp4',
#  'website/59.mp4',
#  'website/590.mp4',
#  'website/591.mp4',
#  'website/592.mp4',
#  'website/593.mp4',
#  'website/594.mp4',
#  'website/595.mp4',
#  'website/596.mp4',
#  'website/597.mp4',
#  'website/598.mp4',
#  'website/599.mp4',
#  'website/6.mp4',
#  'website/60.mp4',
#  'website/600.mp4',
#  'website/601.mp4',
#  'website/602.mp4',
#  'website/603.mp4',
#  'website/604.mp4',
#  'website/605.mp4',
#  'website/606.mp4',
#  'website/607.mp4',
#  'website/608.mp4',
#  'website/609.mp4',
#  'website/61.mp4',
#  'website/610.mp4',
#  'website/611.mp4',
#  'website/612.mp4',
#  'website/613.mp4',
#  'website/614.mp4',
#  'website/615.mp4',
#  'website/616.mp4',
#  'website/617.mp4',
#  'website/618.mp4',
#  'website/619.mp4',
#  'website/62.mp4',
#  'website/620.mp4',
#  'website/621.mp4',
#  'website/622.mp4',
#  'website/623.mp4',
#  'website/624.mp4',
#  'website/625.mp4',
#  'website/626.mp4',
#  'website/627.mp4',
#  'website/628.mp4',
#  'website/629.mp4',
#  'website/63.mp4',
#  'website/630.mp4',
#  'website/631.mp4',
#  'website/632.mp4',
#  'website/633.mp4',
#  'website/634.mp4',
#  'website/635.mp4',
#  'website/636.mp4',
#  'website/637.mp4',
#  'website/638.mp4',
#  'website/639.mp4']

# %% [markdown]
# This will start downloading the videos.

# %%
from huggingface_hub import hf_hub_download

data_path = f"data{start}-{end-1}"
for video in video_list:
    hf_hub_download(repo_id="shuaishuaicdp/GUI-World", filename=video, repo_type="dataset", local_dir=data_path)
# Out:
# 55.mp4:   0%|          | 0.00/1.53M [00:00<?, ?B/s]
# 550.mp4:   0%|          | 0.00/4.69M [00:00<?, ?B/s]
# 551.mp4:   0%|          | 0.00/3.16M [00:00<?, ?B/s]
# 552.mp4:   0%|          | 0.00/5.51M [00:00<?, ?B/s]
# 553.mp4:   0%|          | 0.00/2.77M [00:00<?, ?B/s]
# 554.mp4:   0%|          | 0.00/3.15M [00:00<?, ?B/s]
# 555.mp4:   0%|          | 0.00/3.05M [00:00<?, ?B/s]
# 556.mp4:   0%|          | 0.00/4.11M [00:00<?, ?B/s]
# 557.mp4:   0%|          | 0.00/3.94M [00:00<?, ?B/s]
# 558.mp4:   0%|          | 0.00/3.41M [00:00<?, ?B/s]
# 559.mp4:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# 56.mp4:   0%|          | 0.00/957k [00:00<?, ?B/s]
# 560.mp4:   0%|          | 0.00/2.53M [00:00<?, ?B/s]
# 561.mp4:   0%|          | 0.00/2.74M [00:00<?, ?B/s]
# 562.mp4:   0%|          | 0.00/3.48M [00:00<?, ?B/s]
# 563.mp4:   0%|          | 0.00/3.40M [00:00<?, ?B/s]
# 564.mp4:   0%|          | 0.00/2.57M [00:00<?, ?B/s]
# 565.mp4:   0%|          | 0.00/6.21M [00:00<?, ?B/s]
# 566.mp4:   0%|          | 0.00/1.03M [00:00<?, ?B/s]
# 567.mp4:   0%|          | 0.00/4.96M [00:00<?, ?B/s]
# 568.mp4:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# 569.mp4:   0%|          | 0.00/945k [00:00<?, ?B/s]
# 57.mp4:   0%|          | 0.00/3.03M [00:00<?, ?B/s]
# 570.mp4:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# 571.mp4:   0%|          | 0.00/1.75M [00:00<?, ?B/s]
# 572.mp4:   0%|          | 0.00/993k [00:00<?, ?B/s]
# 573.mp4:   0%|          | 0.00/1.62M [00:00<?, ?B/s]
# 574.mp4:   0%|          | 0.00/2.19M [00:00<?, ?B/s]
# 575.mp4:   0%|          | 0.00/2.06M [00:00<?, ?B/s]
# 576.mp4:   0%|          | 0.00/2.03M [00:00<?, ?B/s]
# 577.mp4:   0%|          | 0.00/2.00M [00:00<?, ?B/s]
# 578.mp4:   0%|          | 0.00/2.96M [00:00<?, ?B/s]
# 579.mp4:   0%|          | 0.00/2.24M [00:00<?, ?B/s]
# 58.mp4:   0%|          | 0.00/1.15M [00:00<?, ?B/s]
# 580.mp4:   0%|          | 0.00/779k [00:00<?, ?B/s]
# 581.mp4:   0%|          | 0.00/772k [00:00<?, ?B/s]
# 582.mp4:   0%|          | 0.00/8.61M [00:00<?, ?B/s]
# 583.mp4:   0%|          | 0.00/871k [00:00<?, ?B/s]
# 584.mp4:   0%|          | 0.00/9.76M [00:00<?, ?B/s]
# 585.mp4:   0%|          | 0.00/920k [00:00<?, ?B/s]
# 586.mp4:   0%|          | 0.00/2.24M [00:00<?, ?B/s]
# 587.mp4:   0%|          | 0.00/2.04M [00:00<?, ?B/s]
# 588.mp4:   0%|          | 0.00/919k [00:00<?, ?B/s]
# 589.mp4:   0%|          | 0.00/10.9M [00:00<?, ?B/s]
# 59.mp4:   0%|          | 0.00/1.71M [00:00<?, ?B/s]
# 590.mp4:   0%|          | 0.00/5.46M [00:00<?, ?B/s]
# 591.mp4:   0%|          | 0.00/8.90M [00:00<?, ?B/s]
# 592.mp4:   0%|          | 0.00/9.95M [00:00<?, ?B/s]
# 593.mp4:   0%|          | 0.00/3.09M [00:00<?, ?B/s]
# 594.mp4:   0%|          | 0.00/4.97M [00:00<?, ?B/s]
# 595.mp4:   0%|          | 0.00/4.66M [00:00<?, ?B/s]
# 596.mp4:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# 597.mp4:   0%|          | 0.00/5.39M [00:00<?, ?B/s]
# 598.mp4:   0%|          | 0.00/3.52M [00:00<?, ?B/s]
# 599.mp4:   0%|          | 0.00/4.92M [00:00<?, ?B/s]
# 6.mp4:   0%|          | 0.00/3.10M [00:00<?, ?B/s]
# 60.mp4:   0%|          | 0.00/2.62M [00:00<?, ?B/s]
# 600.mp4:   0%|          | 0.00/5.46M [00:00<?, ?B/s]
# 601.mp4:   0%|          | 0.00/3.28M [00:00<?, ?B/s]
# 602.mp4:   0%|          | 0.00/5.92M [00:00<?, ?B/s]
# 603.mp4:   0%|          | 0.00/1.43M [00:00<?, ?B/s]
# 604.mp4:   0%|          | 0.00/8.64M [00:00<?, ?B/s]
# 605.mp4:   0%|          | 0.00/13.1M [00:00<?, ?B/s]
# 606.mp4:   0%|          | 0.00/12.4M [00:00<?, ?B/s]
# 607.mp4:   0%|          | 0.00/10.5M [00:00<?, ?B/s]
# 608.mp4:   0%|          | 0.00/7.34M [00:00<?, ?B/s]
# 609.mp4:   0%|          | 0.00/6.99M [00:00<?, ?B/s]
# 61.mp4:   0%|          | 0.00/1.12M [00:00<?, ?B/s]
# 610.mp4:   0%|          | 0.00/5.11M [00:00<?, ?B/s]
# 611.mp4:   0%|          | 0.00/1.49M [00:00<?, ?B/s]
# 612.mp4:   0%|          | 0.00/8.37M [00:00<?, ?B/s]
# 613.mp4:   0%|          | 0.00/7.75M [00:00<?, ?B/s]
# 614.mp4:   0%|          | 0.00/17.9M [00:00<?, ?B/s]
# 615.mp4:   0%|          | 0.00/5.94M [00:00<?, ?B/s]
# 616.mp4:   0%|          | 0.00/12.6M [00:00<?, ?B/s]
# 617.mp4:   0%|          | 0.00/11.8M [00:00<?, ?B/s]
# 618.mp4:   0%|          | 0.00/1.38M [00:00<?, ?B/s]
# 619.mp4:   0%|          | 0.00/15.2M [00:00<?, ?B/s]
# 62.mp4:   0%|          | 0.00/2.72M [00:00<?, ?B/s]
# 620.mp4:   0%|          | 0.00/8.67M [00:00<?, ?B/s]
# 621.mp4:   0%|          | 0.00/4.59M [00:00<?, ?B/s]
# 622.mp4:   0%|          | 0.00/6.14M [00:00<?, ?B/s]
# 623.mp4:   0%|          | 0.00/1.79M [00:00<?, ?B/s]
# 624.mp4:   0%|          | 0.00/3.25M [00:00<?, ?B/s]
# 625.mp4:   0%|          | 0.00/2.30M [00:00<?, ?B/s]
# 626.mp4:   0%|          | 0.00/31.6M [00:00<?, ?B/s]
# 627.mp4:   0%|          | 0.00/7.65M [00:00<?, ?B/s]
# 628.mp4:   0%|          | 0.00/7.68M [00:00<?, ?B/s]
# 629.mp4:   0%|          | 0.00/12.3M [00:00<?, ?B/s]
# 63.mp4:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# 630.mp4:   0%|          | 0.00/3.38M [00:00<?, ?B/s]
# 631.mp4:   0%|          | 0.00/6.40M [00:00<?, ?B/s]
# 632.mp4:   0%|          | 0.00/1.05M [00:00<?, ?B/s]
# 633.mp4:   0%|          | 0.00/8.37M [00:00<?, ?B/s]
# 634.mp4:   0%|          | 0.00/5.37M [00:00<?, ?B/s]
# 635.mp4:   0%|          | 0.00/2.99M [00:00<?, ?B/s]
# 636.mp4:   0%|          | 0.00/6.36M [00:00<?, ?B/s]
# 637.mp4:   0%|          | 0.00/2.50M [00:00<?, ?B/s]
# 638.mp4:   0%|          | 0.00/3.71M [00:00<?, ?B/s]
# 639.mp4:   0%|          | 0.00/7.88M [00:00<?, ?B/s]

# %% [markdown]
# ## 3. Generate embeddings

# %% [markdown]
# ### Swin Transformer

# %% [markdown]
# This part will take up to 5 minutes for each 50 videos. You can increase the `batch_size` in `SWin` for faster embedding, but be aware that it might cause GPU overhead.

# %%
from video2tensor import *

videos_folder = data_path + '/' + video_list[0].split("/")[0]
ft_folder = f"features/swin{start}-{end-1}"
target_fps = 30
batch_size = (256,256)
embedding = SWin(batch_size=64)
embedding.set_model(model_name="test")

video2tensor(videos_folder=videos_folder,target_fps=target_fps,batch_size=batch_size,ft_folder=ft_folder,embedding=embedding)

# Delete caches
torch.cuda.empty_cache()
# Out:
# 100%|██████████| 100/100 [11:27<00:00,  6.88s/it]

# %%
import shutil

# This will zip the embeddings and delete the files
shutil.make_archive(ft_folder, 'zip', ft_folder)
shutil.rmtree(ft_folder)

# %% [markdown]
# ### I3D

# %% [markdown]
# This part will takes about 2 minutes for each 50 videos.
#
#
# > NOTE: You will need to download the pretrained model from https://github.com/piergiaj/pytorch-i3d/blob/master/models/rgb_imagenet.pt

# %%
from video2tensor import *

videos_folder = data_path + '/' + video_list[0].split("/")[0]
ft_folder = f"features/i3d{start}-{end-1}"
target_fps = 30
batch_size = (224, 224)
embedding = I3D()

video2tensor(videos_folder=videos_folder,target_fps=target_fps,batch_size=batch_size,ft_folder=ft_folder,embedding=embedding)

# Delete caches
torch.cuda.empty_cache()
# Out:
# 100%|██████████| 100/100 [03:56<00:00,  2.37s/it]

# %%
import shutil

# This will zip the embeddings and delete the files
shutil.make_archive(ft_folder, 'zip', ft_folder)
shutil.rmtree(ft_folder)

# %% [markdown]
# ## 4. Delete downloaded videos
#
# You can comment below codes if you want to preserve your videos (and if your storage space is large enough :D)

# %%
import os

for video in video_list:
  file_to_delete = os.path.join(data_path, video)
  if os.path.exists(file_to_delete):
    print(f"Remove {file_to_delete}")
    os.remove(file_to_delete)
  else:
    print(f"The file {file_to_delete} does not exist")
# Out:
# Remove data2000-2099/website/55.mp4
# Remove data2000-2099/website/550.mp4
# Remove data2000-2099/website/551.mp4
# Remove data2000-2099/website/552.mp4
# Remove data2000-2099/website/553.mp4
# Remove data2000-2099/website/554.mp4
# Remove data2000-2099/website/555.mp4
# Remove data2000-2099/website/556.mp4
# Remove data2000-2099/website/557.mp4
# Remove data2000-2099/website/558.mp4
# Remove data2000-2099/website/559.mp4
# Remove data2000-2099/website/56.mp4
# Remove data2000-2099/website/560.mp4
# Remove data2000-2099/website/561.mp4
# Remove data2000-2099/website/562.mp4
# Remove data2000-2099/website/563.mp4
# Remove data2000-2099/website/564.mp4
# Remove data2000-2099/website/565.mp4
# Remove data2000-2099/website/566.mp4
# Remove data2000-2099/website/567.mp4
# Remove data2000-2099/website/568.mp4
# Remove data2000-2099/website/569.mp4
# Remove data2000-2099/website/57.mp4
# Remove data2000-2099/website/570.mp4
# Remove data2000-2099/website/571.mp4
# Remove data2000-2099/website/572.mp4
# Remove data2000-2099/website/573.mp4
# Remove data2000-2099/website/574.mp4
# Remove data2000-2099/website/575.mp4
# Remove data2000-2099/website/576.mp4
# Remove data2000-2099/website/577.mp4
# Remove data2000-2099/website/578.mp4
# Remove data2000-2099/website/579.mp4
# Remove data2000-2099/website/58.mp4
# Remove data2000-2099/website/580.mp4
# Remove data2000-2099/website/581.mp4
# Remove data2000-2099/website/582.mp4
# Remove data2000-2099/website/583.mp4
# Remove data2000-2099/website/584.mp4
# Remove data2000-2099/website/585.mp4
# Remove data2000-2099/website/586.mp4
# Remove data2000-2099/website/587.mp4
# Remove data2000-2099/website/588.mp4
# Remove data2000-2099/website/589.mp4
# Remove data2000-2099/website/59.mp4
# Remove data2000-2099/website/590.mp4
# Remove data2000-2099/website/591.mp4
# Remove data2000-2099/website/592.mp4
# Remove data2000-2099/website/593.mp4
# Remove data2000-2099/website/594.mp4
# Remove data2000-2099/website/595.mp4
# Remove data2000-2099/website/596.mp4
# Remove data2000-2099/website/597.mp4
# Remove data2000-2099/website/598.mp4
# Remove data2000-2099/website/599.mp4
# Remove data2000-2099/website/6.mp4
# Remove data2000-2099/website/60.mp4
# Remove data2000-2099/website/600.mp4
# Remove data2000-2099/website/601.mp4
# Remove data2000-2099/website/602.mp4
# Remove data2000-2099/website/603.mp4
# Remove data2000-2099/website/604.mp4
# Remove data2000-2099/website/605.mp4
# Remove data2000-2099/website/606.mp4
# Remove data2000-2099/website/607.mp4
# Remove data2000-2099/website/608.mp4
# Remove data2000-2099/website/609.mp4
# Remove data2000-2099/website/61.mp4
# Remove data2000-2099/website/610.mp4
# Remove data2000-2099/website/611.mp4
# Remove data2000-2099/website/612.mp4
# Remove data2000-2099/website/613.mp4
# Remove data2000-2099/website/614.mp4
# Remove data2000-2099/website/615.mp4
# Remove data2000-2099/website/616.mp4
# Remove data2000-2099/website/617.mp4
# Remove data2000-2099/website/618.mp4
# Remove data2000-2099/website/619.mp4
# Remove data2000-2099/website/62.mp4
# Remove data2000-2099/website/620.mp4
# Remove data2000-2099/website/621.mp4
# Remove data2000-2099/website/622.mp4
# Remove data2000-2099/website/623.mp4
# Remove data2000-2099/website/624.mp4
# Remove data2000-2099/website/625.mp4
# Remove data2000-2099/website/626.mp4
# Remove data2000-2099/website/627.mp4
# Remove data2000-2099/website/628.mp4
# Remove data2000-2099/website/629.mp4
# Remove data2000-2099/website/63.mp4
# Remove data2000-2099/website/630.mp4
# Remove data2000-2099/website/631.mp4
# Remove data2000-2099/website/632.mp4
# Remove data2000-2099/website/633.mp4
# Remove data2000-2099/website/634.mp4
# Remove data2000-2099/website/635.mp4
# Remove data2000-2099/website/636.mp4
# Remove data2000-2099/website/637.mp4
# Remove data2000-2099/website/638.mp4
# Remove data2000-2099/website/639.mp4

# %% [markdown]
# Remove the entire data path

# %%
import shutil

shutil.rmtree(f'data{start}-{end-1}')
