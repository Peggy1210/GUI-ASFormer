# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# frame extraction

# %%
import os 
from video2tensor import *
abspath = os.path.join(os.getcwd(),'..')
videos_folder = os.path.join(abspath,'videos')
ft_folder = os.path.join(abspath,'features')
target_fps = 30
batch_size = (256,256)
embedding = ImgEmbedding()
embedding.set_model(model_name="test")

video2tensor(videos_folder=videos_folder,target_fps=target_fps,batch_size=batch_size,ft_folder=ft_folder,embedding=embedding)
# Out:
# Processing Video: 100%|██████████| 500/500 [01:15<00:00,  6.59it/s]
#  17%|█▋        | 1/6 [01:16<06:24, 76.86s/it]
# final embedding shape: torch.Size([2048, 500])
# Processing Video: 100%|██████████| 297/297 [00:50<00:00,  5.91it/s]
#  33%|███▎      | 2/6 [02:07<04:06, 61.55s/it]
# final embedding shape: torch.Size([2048, 297])
# Processing Video: 100%|██████████| 152/152 [00:26<00:00,  5.64it/s]
#  67%|██████▋   | 4/6 [02:34<01:03, 31.51s/it]
# final embedding shape: torch.Size([2048, 152])
# Processing Video: 100%|██████████| 251/251 [00:46<00:00,  5.44it/s]
#  83%|████████▎ | 5/6 [03:21<00:36, 36.21s/it]
# final embedding shape: torch.Size([2048, 251])
# Processing Video: 100%|██████████| 233/233 [00:41<00:00,  5.60it/s]
# 100%|██████████| 6/6 [04:03<00:00, 40.63s/it]
# final embedding shape: torch.Size([2048, 233])

# %%
10**(-2)*59/60*0.2+10**(-2)*0.05*0.8+10**-2+10**(-4)*2
# Out:
# 0.012566666666666667
